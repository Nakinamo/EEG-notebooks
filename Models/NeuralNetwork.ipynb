# %%
# !pip install proglog
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting proglog
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from proglog) (4.64.0)
# Installing collected packages: proglog
# Successfully installed proglog-0.1.10

# %%
import proglog 
proglog.notebook()

# %%
from sklearn.preprocessing import QuantileTransformer
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error
from sklearn import linear_model

# %%
# !gdown 1WwyO371fkmnxtdJITPQqrOirkdUnfR7L
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WwyO371fkmnxtdJITPQqrOirkdUnfR7L
# To: /content/Matrix_complexity.csv
# 100% 1.39M/1.39M [00:00<00:00, 89.8MB/s]

# %%
data_all = pd.read_csv('/content/Matrix_complexity.csv')
for column in data_all.columns:
    data_all[column] = data_all[column].fillna(data_all[column].mean())

# %%
models = ['NN']
metrics = ['MAPE', 'MAE']
formes = ['inverted', 'average']
columns = [
    np.array([models[i] for i in range(1) for j in range(2) for k in range(2)]),
    np.array([metrics[j] for i in range(1) for j in range(2) for k in range(2)]),
    np.array([formes[k] for i in range(1) for j in range(2) for k in range(2)]),
]
chans = ['Fz', 'F3', 'F7','C3', 'T7', 'Pz', 'P3','P7', 'O1', 'Oz', 'O2','P4', 'P8', 'Cz','C4', 'T8', 'F4', 'F8']

# %%
from keras.layers.advanced_activations import LeakyReLU
import keras
import tqdm
import copy
from keras import layers

# %%
def evaluate_model(model, epochs):
  result = pd.DataFrame()
  grid_res = []
  n_films = 8
  n_subjects = 32

  for film in tqdm.tqdm_notebook(range(1, n_films + 1)):
    X_test = data_all.loc[(data_all['film'] == film)].reset_index(drop=True)
    
    X_train = data_all.loc[(data_all['film'] != film)].reset_index(drop=True)
    X_train = X_train.sample(frac=1)
    X_test = X_test.sample(frac=1)

    y_train = X_train['Labels']
    y_test = X_test['Labels']

    X_train = X_train.drop(['film', 'Subj', 'Labels'], axis=1)
    X_test = X_test.drop(['film', 'Subj', 'Labels'], axis=1)

    m = copy.deepcopy(model)

    m.compile(optimizer='adam', loss='mean_squared_error', metrics=metrics)

    m.fit(
        X_train,
        y_train,
        epochs=epochs, verbose=0)
    
    m.evaluate(X_train, y_train)
    m.evaluate(X_test, y_test)
    print('\n')

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.BatchNormalization(),
      layers.Dense(256,),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.BatchNormalization(),
      layers.Dense(1, activation='relu'),
  ]),
  1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 1s 7ms/step - loss: 1.1421 - MAPE: 19.6016 - MAE: 0.8041
# 1/1 [==============================] - 0s 52ms/step - loss: 11.0181 - MAPE: 38.6598 - MAE: 2.7182
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1346 - MAPE: 23.3047 - MAE: 0.7661
# 1/1 [==============================] - 0s 22ms/step - loss: 5.0481 - MAPE: 33.4143 - MAE: 1.7253
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9035 - MAPE: 19.9358 - MAE: 0.6711
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0274 - MAPE: 61.4798 - MAE: 2.1725
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9056 - MAPE: 15.8133 - MAE: 0.6637
# 1/1 [==============================] - 0s 25ms/step - loss: 6.6201 - MAPE: 52.1746 - MAE: 2.1039
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1731 - MAPE: 23.0769 - MAE: 0.8277
# 1/1 [==============================] - 0s 23ms/step - loss: 8.4522 - MAPE: 67.6879 - MAE: 2.3129
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 1.1303 - MAPE: 18.8828 - MAE: 0.7485
# 1/1 [==============================] - 0s 27ms/step - loss: 3.9410 - MAPE: 34.5218 - MAE: 1.4301
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 1.5370 - MAPE: 21.9489 - MAE: 0.8785
# 1/1 [==============================] - 0s 23ms/step - loss: 6.3929 - MAPE: 38.6935 - MAE: 2.0444
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 0.8757 - MAPE: 17.2564 - MAE: 0.7506
# 1/1 [==============================] - 0s 26ms/step - loss: 8.2488 - MAPE: 81.4095 - MAE: 2.2515

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.BatchNormalization(),
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.BatchNormalization(),
      layers.Dense(1, activation='relu'),
  ]),
  1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1146 - MAPE: 36.2319 - MAE: 1.3941
# 1/1 [==============================] - 0s 24ms/step - loss: 7.3419 - MAPE: 32.1970 - MAE: 2.3576
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.4094 - MAPE: 37.2729 - MAE: 1.4772
# 1/1 [==============================] - 0s 22ms/step - loss: 5.5286 - MAPE: 40.1903 - MAE: 1.7963
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.1614 - MAPE: 37.4352 - MAE: 1.4160
# 1/1 [==============================] - 0s 28ms/step - loss: 9.0730 - MAPE: 77.6477 - MAE: 2.5444
#
#
# 5/5 [==============================] - 0s 6ms/step - loss: 3.6205 - MAPE: 39.2624 - MAE: 1.5295
# 1/1 [==============================] - 0s 25ms/step - loss: 6.6326 - MAPE: 53.5225 - MAE: 2.1076
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.6014 - MAPE: 36.5249 - MAE: 1.5481
# 1/1 [==============================] - 0s 25ms/step - loss: 10.9828 - MAPE: 87.9109 - MAE: 2.7919
#
#
# 5/5 [==============================] - 0s 6ms/step - loss: 3.7379 - MAPE: 38.9887 - MAE: 1.5528
# 1/1 [==============================] - 0s 30ms/step - loss: 4.3564 - MAPE: 42.5344 - MAE: 1.7345
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.6991 - MAPE: 40.4249 - MAE: 1.5428
# 1/1 [==============================] - 0s 26ms/step - loss: 6.0073 - MAPE: 40.4759 - MAE: 2.1681
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.0347 - MAPE: 32.7206 - MAE: 1.4008
# 1/1 [==============================] - 0s 25ms/step - loss: 8.3497 - MAPE: 93.1096 - MAE: 2.4113

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.BatchNormalization(),
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.BatchNormalization(),
      layers.Dense(1, activation='relu'),
  ]),
  100
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 0s 4ms/step - loss: 3.6371 - MAPE: 44.7094 - MAE: 1.5465
# 1/1 [==============================] - 0s 26ms/step - loss: 6.7948 - MAPE: 35.3589 - MAE: 2.3409
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.8526 - MAPE: 45.5926 - MAE: 1.6262
# 1/1 [==============================] - 0s 25ms/step - loss: 3.3700 - MAPE: 33.7565 - MAE: 1.5972
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 4.7483 - MAPE: 49.0099 - MAE: 1.7276
# 1/1 [==============================] - 0s 26ms/step - loss: 8.7136 - MAPE: 76.0112 - MAE: 2.5214
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 4.0774 - MAPE: 37.6443 - MAE: 1.6218
# 1/1 [==============================] - 0s 25ms/step - loss: 6.7502 - MAPE: 55.2755 - MAE: 2.2680
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.3439 - MAPE: 37.8847 - MAE: 1.5302
# 1/1 [==============================] - 0s 25ms/step - loss: 7.0775 - MAPE: 60.4133 - MAE: 2.1277
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 4.2734 - MAPE: 47.4085 - MAE: 1.6666
# 1/1 [==============================] - 0s 24ms/step - loss: 4.4403 - MAPE: 41.1544 - MAE: 1.5051
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 4.5881 - MAPE: 41.9361 - MAE: 1.7239
# 1/1 [==============================] - 0s 25ms/step - loss: 4.7100 - MAPE: 32.6291 - MAE: 1.8291
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.5282 - MAPE: 35.1846 - MAE: 1.5024
# 1/1 [==============================] - 0s 23ms/step - loss: 7.1276 - MAPE: 83.6219 - MAE: 2.3168

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.BatchNormalization(),
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.BatchNormalization(),
      layers.Dense(1, activation='relu'),
  ]),
  100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 0s 4ms/step - loss: 11.6315 - MAPE: 71.0091 - MAE: 2.6745
# 1/1 [==============================] - 0s 26ms/step - loss: 14.1107 - MAPE: 42.1214 - MAE: 2.7207
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 11.5438 - MAPE: 79.0644 - MAE: 2.6856
# 1/1 [==============================] - 0s 21ms/step - loss: 12.6641 - MAPE: 65.9405 - MAE: 2.7848
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 14.7083 - MAPE: 86.3549 - MAE: 3.0956
# 1/1 [==============================] - 0s 25ms/step - loss: 26.1200 - MAPE: 135.2040 - MAE: 4.8074
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 10.1213 - MAPE: 70.2711 - MAE: 2.5482
# 1/1 [==============================] - 0s 29ms/step - loss: 10.9096 - MAPE: 74.4905 - MAE: 2.4342
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 10.2438 - MAPE: 68.6584 - MAE: 2.6029
# 1/1 [==============================] - 0s 24ms/step - loss: 18.1530 - MAPE: 124.1635 - MAE: 3.3734
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 10.3107 - MAPE: 71.5058 - MAE: 2.5126
# 1/1 [==============================] - 0s 27ms/step - loss: 10.1434 - MAPE: 61.1456 - MAE: 2.5811
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 14.2248 - MAPE: 88.1395 - MAE: 3.1206
# 1/1 [==============================] - 0s 23ms/step - loss: 10.3595 - MAPE: 58.6841 - MAE: 2.4186
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 11.6189 - MAPE: 72.3241 - MAE: 2.7398
# 1/1 [==============================] - 0s 28ms/step - loss: 20.5198 - MAPE: 138.1726 - MAE: 3.7864

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.Dense(256,),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.Dense(1, activation='relu'),
  ]),
  1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 0s 5ms/step - loss: 42.3793 - MAPE: 100.0000 - MAE: 6.0621
# 1/1 [==============================] - 0s 27ms/step - loss: 61.6190 - MAPE: 100.0000 - MAE: 7.5238
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 44.5959 - MAPE: 100.0000 - MAE: 6.2123
# 1/1 [==============================] - 0s 31ms/step - loss: 46.4000 - MAPE: 100.0000 - MAE: 6.5000
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 47.4276 - MAPE: 100.0000 - MAE: 6.4483
# 1/1 [==============================] - 0s 38ms/step - loss: 26.7619 - MAPE: 100.0000 - MAE: 4.8571
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 43.9862 - MAPE: 100.0000 - MAE: 6.1931
# 1/1 [==============================] - 0s 26ms/step - loss: 50.5238 - MAPE: 100.0000 - MAE: 6.6190
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 44.0828 - MAPE: 100.0000 - MAE: 6.2069
# 1/1 [==============================] - 0s 26ms/step - loss: 49.8571 - MAPE: 100.0000 - MAE: 6.5238
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 45.2808 - MAPE: 100.0000 - MAE: 6.2671
# 1/1 [==============================] - 0s 27ms/step - loss: 41.4000 - MAPE: 100.0000 - MAE: 6.1000
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 44.5241 - MAPE: 100.0000 - MAE: 6.2069
# 1/1 [==============================] - 0s 26ms/step - loss: 46.8095 - MAPE: 100.0000 - MAE: 6.5238
#
#
# 5/5 [==============================] - 0s 7ms/step - loss: 46.2276 - MAPE: 100.0000 - MAE: 6.3793
# 1/1 [==============================] - 0s 29ms/step - loss: 35.0476 - MAPE: 100.0000 - MAE: 5.3333

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.Dense(256, activation='sigmoid'),
      layers.Dropout(0.2),
      layers.Dense(1, activation='relu'),
  ]),
  1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys
#   0%|          | 0/8 [00:00<?, ?it/s]
# 5/5 [==============================] - 0s 4ms/step - loss: 3.7007 - MAPE: 42.2827 - MAE: 1.5292
# 1/1 [==============================] - 0s 29ms/step - loss: 7.9271 - MAPE: 34.7043 - MAE: 2.5073
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 4.2091 - MAPE: 46.6845 - MAE: 1.6785
# 1/1 [==============================] - 0s 23ms/step - loss: 4.7574 - MAPE: 37.3144 - MAE: 1.6494
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.5003 - MAPE: 37.1903 - MAE: 1.4928
# 1/1 [==============================] - 0s 26ms/step - loss: 7.9417 - MAPE: 72.7039 - MAE: 2.4490
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.7191 - MAPE: 40.3877 - MAE: 1.5372
# 1/1 [==============================] - 0s 22ms/step - loss: 6.7406 - MAPE: 50.9779 - MAE: 2.1995
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.4490 - MAPE: 36.1329 - MAE: 1.4947
# 1/1 [==============================] - 0s 30ms/step - loss: 9.7816 - MAPE: 88.5564 - MAE: 2.5865
#
#
# 5/5 [==============================] - 0s 4ms/step - loss: 3.9086 - MAPE: 40.6576 - MAE: 1.5909
# 1/1 [==============================] - 0s 23ms/step - loss: 4.9824 - MAPE: 42.7259 - MAE: 1.8296
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.9610 - MAPE: 44.4910 - MAE: 1.5872
# 1/1 [==============================] - 0s 23ms/step - loss: 5.8639 - MAPE: 39.7077 - MAE: 2.0052
#
#
# 5/5 [==============================] - 0s 5ms/step - loss: 3.4069 - MAPE: 36.0060 - MAE: 1.4743
# 1/1 [==============================] - 0s 30ms/step - loss: 8.1537 - MAPE: 88.4724 - MAE: 2.3115

# %%
evaluate_model(
    keras.Sequential([
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.Dense(256),
      layers.Dropout(0.2),
      layers.LeakyReLU(),
      layers.Dense(1, activation='relu'),
  ]),
  100
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   import sys